# %%
import qiskit
import numpy as np
import sys

import tqix as tq

# %%
# set inital circuit parameters 
num_qubits = 4
t = 1.0
y = 0.1

# set initial parameters
phases = [np.pi/6.,np.pi/6.,np.pi/6.]


# set intial circuits
qcir1 = [star_graph, None, None]
qcir2 = [u_phase,t,phases]
qcir3 = [markovian,t,y]


# input circuit
qcirs =[qcir1, qcir2,qcir3]

# setup a model 
qc = qiskit.QuantumCircuit(num_qubits, num_qubits)
model = qc_add(qc, qcirs)
model.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 11
#       7 phases = [np.pi/6.,np.pi/6.,np.pi/6.]
#      10 # set intial circuits
# ---> 11 qcir1 = [star_graph, None, None]
#      12 qcir2 = [u_phase,t,phases]
#      13 qcir3 = [markovian,t,y]
#
# NameError: name 'star_graph' is not defined

# %%
# quantum fisher information matrix
qc = qiskit.QuantumCircuit(num_qubits,num_qubits)
qbound = sld_bound(qc,qcirs)
print(qbound)

# %%
# running vs Markovian noise

num_qubits = 5
tm = 4.0
y = 0.5 #fix
phases = [np.pi/10.,np.pi/10.,np.pi/10.]

qbound_mar = []
qbound_nonmar = []
ts = np.linspace(0.1,tm,100)

for t in ts:   
    # set intial circuits
    qcir1_ghz = [ghz, None, None]
    qcir1_star = [star_graph, None, None]   
    qcir2 = [u_phase,t,phases]    
    qcir3_mar = [markovian,t,y]
    qcir3_nonmar = [non_markovian,t,y]


    # input circuit
    qcirs_star_mar =[qcir1_star, qcir2, qcir3_mar]
    qcirs_star_nonmar =[qcir1_star, qcir2, qcir3_nonmar]
        
    # setup a model 
    qc = qiskit.QuantumCircuit(num_qubits, num_qubits)   
    
    # quantum bound
    qbound_mar.append(sld_bound(qc.copy(),qcirs_star_mar))
    qbound_nonmar.append(sld_bound(qc.copy(),qcirs_star_nonmar))
    
print(qbound_mar)  
print(qbound_nonmar)

# %%
# plot figure   
import matplotlib.pyplot as plt

#data
mar_05_pi6 = [13.39866260363014, 6.992894452202362, 4.31326523414473, 2.9404098186372183, 2.1428686817354636, 1.6380060818811932, 1.2977969215536258, 1.0573482849624312, 0.8808955164631809, 0.7475179225436219, 0.6440938808250134, 0.5620826735957529, 0.4958742636991442, 0.4416927256461586, 0.39691981066095144, 0.35967782201817633, 0.3285521684936728, 0.3024075016065756, 0.28027689709583414, 0.26129530415341085, 0.24473064748712295, 0.23083457217668707, 0.21851138929219466, 0.20749406359990658, 0.19763066015800138, 0.18892873221496725, 0.18145775257351313, 0.17524826376696284, 0.17022291240114462, 0.16617335753867957, 0.16279867855772223, 0.15981392400701988, 0.15706754776085188, 0.15457483398662608, 0.15252796378920158, 0.1508919542716272, 0.14923837602572015, 0.14809343405283756, 0.14777051566717103, 0.14845020290450223, 0.15032151668065685, 0.15357211004877896, 0.1583959566228453, 0.16501319049359384, 0.1736936593215649, 0.18478063471823494, 0.19871239654177064, 0.21603751551866082, 0.2374141330717079, 0.2635746344683073, 0.29522695740067884, 0.33285835371363226, 0.3764212859764309, 0.42493852902288465, 0.4761777931451753, 0.5266608732073126, 0.5722403519331425, 0.6091696729458771, 0.6352413014751577, 0.6503756686056579, 0.6564694404051533, 0.6566766842115013, 0.654558738338245, 0.6534483452070564, 0.6561602885394477, 0.6650060851606444, 0.6820053208296925, 0.709202530399492, 0.749040063162686, 0.8047
.07097168258507378, 0.06801453409480254, 0.0652892725281368, 0.06277387449196234, 0.06044895590665918, 0.05829739880099178, 0.05630404302569447, 0.05445542459778076, 0.05273955401281406, 0.051145728077768335, 0.04966437001093, 0.048286893339424625, 0.047005585702208315, 0.045813509388906895, 0.044704415680346644, 0.04367267088050457, 0.042713192495537206, 0.04182139449101583, 0.04099314075548878, 0.040224705328984915, 0.03951273740881407, 0.03885422965370526, 0.03824649021015057, 0.037687114191601326, 0.03717392865255587, 0.036704912360084704, 0.03627825536061516, 0.035892461781265865, 0.035546233618653666, 0.03523841497364891, 0.03496800650685441, 0.03473416689616651, 0.034536206053562266, 0.034373578150870304, 0.0342458761963486, 0.03415282816587092, 0.03409429437422574, 0.03407026583390199, 0.034080863264167864, 0.034126336463479685, 0.034207063831535656, 0.034323551893748444, 0.03447643486761704, 0.034666474252793414, 0.03489455866385687, 0.03516170404994965, 0.035469054473659396, 0.03581788366468208, 0.03620959764372085, 0.03664573880929725, 0.03712799200146322, 0.037658193129206576, 0.038238341095113114, 0.038870613692846084, 0.03955738827371368, 0.04030126802307388, 0.041105114609249385, 0.0419720883913547, 0.04290569701072819, 0.04390985368668488, 0.044988947938127716, 0.046147917534761274, 0.04739236145799345, 0.04872863085205409, 0.05016396482153566]


plt.subplot(1, 2, 1)
plt.ylim(0,1)
#plt.errorbar(x, ave_ghz, std_ghz, marker='v',  ms=4, mew=2)
#plt.errorbar(x, ave_w, std_w, marker='^',  ms=4, mew=2)
plt.plot(ts, mar_05_pi6, '-.',label='Mar_0.5_pi_6')
plt.plot(ts, nonmar_05_pi6, '-',label='nonMar_0.5_pi_6')
plt.plot(ts, mar_10_pi6, '-.',label='Mar_1.0_pi_6')
plt.plot(ts, nonmar_10_pi6, '-',label='nonMar_1.0_pi_6')
plt.legend()

#plot 2: N = 8
plt.subplot(1, 2, 2)
plt.ylim(0,1)
plt.plot(ts, mar_05_pi6, '-.',label='Mar_0.5_pi_6')
plt.plot(ts, nonmar_05_pi6, '-',label='nonMar_0.5_pi_6')
plt.plot(ts, mar_05_pi10, '-.',label='Mar_0.5_pi_10')
plt.plot(ts, nonmar_05_pi10, '-',label='nonMar_0.5_pi_10')

plt.legend()

plt.savefig('3D_noise_phase.eps')
plt.show()


#plt.legend()
#plt.show()

# %%
# run for N
num_qubits = 5
tm = 3.0
y = 1.0 #fix
phases = [np.pi/6.,np.pi/6.,np.pi/6.]

qbound_mar = []
qbound_nonmar = []
ts = np.linspace(0.1,tm,100)

for t in ts:   
    # set intial circuits
    qcir1_ghz = [ghz, None, None]
    qcir1_star = [star_graph, None, None]   
    qcir2 = [u_phase,t,phases]    
    qcir3_mar = [markovian,t,y]
    qcir3_nonmar = [non_markovian,t,y]


    # input circuit
    qcirs_star_mar =[qcir1_star, qcir2, qcir3_mar]
    qcirs_star_nonmar =[qcir1_star, qcir2, qcir3_nonmar]
        
    # setup a model 
    qc = qiskit.QuantumCircuit(num_qubits, num_qubits)   
    
    # quantum bound
    qbound_mar.append(sld_bound(qc.copy(),qcirs_star_mar))
    qbound_nonmar.append(sld_bound(qc.copy(),qcirs_star_nonmar))

    
# find min qbound
mar_min = min(qbound_mar)
mar_index = np.argmin(qbound_mar)
nonmar_min = min(qbound_nonmar)
nonmar_index = np.argmin(qbound_nonmar)

print(ts[mar_index],mar_min)
print(ts[nonmar_index],nonmar_min)


#plot figure to check min
import matplotlib.pyplot as plt
#first plot
plt.subplot(1, 2, 1)
plt.ylim(0,1)
plt.plot(ts, qbound_mar, '-.',label='Mar_0.5_pi_6')
plt.plot(ts, qbound_nonmar, '-',label='Mar_0.5_pi_6')
plt.savefig('multiple_N5_time.eps')
# Out:
# 1.183838383838384 0.2659508290784133
# 1.7696969696969698 0.09320134443396519

# %%
# plot figure with N  
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator, AutoMinorLocator

num_qubits = [3,4,5,6,7,8,9]

mar_bound = [0.3086706139268889,0.19601509657565555,0.14776214745813362,0.11571108865335107,0.09620141046415549,0.08244278853326488,0.07185046767048536]
mar_time = [1.798989898989899,1.5646464646464646,1.593939393939394,1.506060606060606,1.506060606060606,1.4767676767676767,1.4767676767676767]

nonmar_bound = [0.19184646576107614,0.12496163403286366,0.09139103265974265,0.07179423735565871,0.059070315159716225,0.05017070621656179,0.043604163389877035]
nonmar_time = [1.798989898989899,1.798989898989899,1.798989898989899,1.798989898989899,1.798989898989899,1.798989898989899,1.798989898989899]

num_qubits_y1 = [3,4,5,6,7,8,9]
mar_bound_y1 = [0.6091562186543151,0.33093623566721164,0.2659508290784133,0.19303298103662825,0.17041386631621414,0.13681211155848214,0.12433543936588083]
mar_time_y1 = [1.213131313131313,1.506060606060606,1.183838383838384,1.4181818181818182,1.183838383838384,1.3595959595959597,1.1474747474747474]

nonmar_bound_y1 = [0.19498052186698384,0.1271634726069891,0.09320134443396519,0.0733368487737911,0.06042123053976056,0.051376534493926304,0.04469730148383194]
nonmar_time_y1 = [1.798989898989899,1.798989898989899,1.7696969696969698,1.7696969696969698,1.7696969696969698,1.7696969696969698,1.7696969696969698 ]

num_qubits_1 = np.arange(1, 10, 1)
SQL = 1/num_qubits_1
HL = 1/num_qubits_1**2

#first plot
plt.subplot(1, 2, 1)
plt.plot(num_qubits, mar_time, '-v',label='mar')
plt.plot(num_qubits, nonmar_time, '-^',label='nonmar')
plt.plot(num_qubits_y1, mar_time_y1, '-v',label='mar')
plt.plot(num_qubits_y1, nonmar_time_y1, '-^',label='nonmar')
plt.ylim(0.6,1.85)
plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(plt.LogLocator(base=10.0, subs=np.arange(2, 10) * 0.1))
#plt.gca().yaxis.set_minor_locator(plt.AutoMinorLocator())
#plt.xscale('log')
#plt.yscale('log')

#second plot
plt.subplot(1, 2, 2)
plt.plot(num_qubits, mar_bound, 'v',label='mar_noise_0.5_pi6')
plt.plot(num_qubits, nonmar_bound, '^',label='nonmar_noise_0.5_pi6')

plt.plot(num_qubits_y1, mar_bound_y1, 'v',label='mar_noise_1.0_pi6')
plt.plot(num_qubits_y1, nonmar_bound_y1, '^',label='nonmar_noise_1.0_pi6')

plt.plot(num_qubits_1, SQL, '-')
plt.plot(num_qubits_1, HL, '-')

plt.xscale('log')
plt.yscale('log')
plt.legend(loc='lower left')
plt.savefig('multiple_N.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# compare with GHZ
from tqix import *
num_qubits = 3
sigx = soper(1,'z'),
print(sigx)

tm = 3.0
y = 1.0 #fix
phases = [np.pi/6.,np.pi/6.,np.pi/6.]

qbound_mar = []
qbound_nonmar = []
ts = np.linspace(0.1,tm,100)
# Out:
# (array([[ 1.+0.j,  0.+0.j,  0.+0.j],
#        [ 0.+0.j,  0.+0.j,  0.+0.j],
#        [ 0.+0.j,  0.+0.j, -1.+0.j]]),)
